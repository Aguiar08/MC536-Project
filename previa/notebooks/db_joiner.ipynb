# %%
#Código que junta todos os csvs da pasta games
import pandas as pd
import glob

# %%
def lichessFixer(white, black, winner):
    if winner == 'white':
        return white
    else:
        return black

# %%
path = r'../data/interim/lichesswithop/' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)
frame.drop_duplicates(subset=['id'],inplace=True)
frame['winner'] = frame.apply(lambda x: lichessFixer(x['white'], x['black'], x['winner']))
frame['site_name'] = 'lichess'
frame.to_csv('../data/interim/all_games_lichess.csv',index=False)

# %%
path = r'../data/interim/chessdotcomwithop/' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)
frame.drop_duplicates(subset=['id'],inplace=True)
frame['site_name'] = 'chess.com'
frame.to_csv('../data/interim/all_games_chessdotcom.csv',index=False)

# %%
path = r'../data/interim/'
file1 = 'all_games_chessdotcom.csv'
file2 = 'all_games_lichess.csv'
frame1 = pd.read_csv(path+file1)
frame2 = pd.read_csv(path+file2)

frame = pd.concat([frame1,frame2],ignore_index=True)
# Out:
# C:\Users\eduar\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
frame.drop(columns=['Unnamed: 0'], inplace=True)
frame.dropna(inplace=True)
frame.to_csv('../data/processed/all_games.csv')
frame
# Out:
#                                           id ranked time_control      status  \
# 0       b4a71732-5bd0-11e1-8000-000000010001   True       bullet  checkmated
# 1       a0afe550-5bd1-11e1-8000-000000010001   True       bullet  checkmated
# 2       495e4494-5bd2-11e1-8000-000000010001   True       bullet     timeout
# 3       05b80a80-5bd3-11e1-8000-000000010001   True       bullet    resigned
# 4       752dfa64-5bd3-11e1-8000-000000010001   True       bullet     timeout
# ...                                      ...    ...          ...         ...
# 890295                              qIrvcH75   True       bullet      resign
# 890296                              e7fWbQcG   True       bullet        mate
# 890297                              p1LZEQk6   True       bullet        mate
# 890298                              eyq31n6a   True       bullet        mate
# 890299                              TlIK7aqI   True       bullet      resign
#
#          winner                white                black  \
# 0       shnitez              shnitez       spencerkinney1
# 1       shnitez              knujra1              shnitez
# 2       shnitez               rxjx01              shnitez
# 3       shnitez              shnitez   Adventure_Binaural
# 4       shnitez              shnitez              e-profe
# ...         ...                  ...                  ...
# 890295    black               Ozelle  Clown_laughing_at_u
# 890296    black               b0stja  Clown_laughing_at_u
# 890297    white  Clown_laughing_at_u           Nikolaev_O
# 890298    black            fatihhant  Clown_laughing_at_u
# 890299    white  Clown_laughing_at_u                Jodee
#
#                                                     moves  \
# 0       1. e4 Nf6 2. e5 Nd5 3. d4 d6 4. Nf3 Bg4 5. Be2...
# 1       1. e4 c5 2. Nf3 d6 3. Nc3 Nf6 4. d4 cxd4 5. Nx...
# 2       1. e4 c5 2. Bc4 e6 3. Nc3 a6 4. a4 Nc6 5. Nf3 ...
# 3       1. a4 c5 2. Ra3 Nc6 3. Rg3 g6 4. h4 Bh6 5. h5 ...
# 4       1. e4 c5 2. Nf3 Nc6 3. Bb5 g6 4. Bxc6 dxc6 5. ...
# ...                                                   ...
# 890295  1. e4 e5 2. Nf3 Nc6 3. Bc4 Bc5 4. b4 Bxb4 5. c...
# 890296  1. d4 Nf6 2. Nf3 d5 3. e3 e6 4. Bd3 Bd6 5. O-O...
# 890297  1. e4 c6 2. d4 d5 3. exd5 cxd5 4. c4 Nc6 5. Nc...
# 890298  1. d4 d5 2. Bg5 Nf6 3. Bxf6 exf6 4. e3 Bd6 5. ...
# 890299  1. e4 e6 2. d4 c6 3. Nd2 a6 4. e5 b5 5. Ngf3 g...
#
#                                                   opening  site_name
# 0           Alekhine Defense: Modern Variation, Main Line  chess.com
# 1                     Sicilian Defense: Modern Variations  chess.com
# 2                        Sicilian Defense: Bowdler Attack  chess.com
# 3                                            Ware Opening  chess.com
# 4       Sicilian Defense: Nyezhmetdinov-Rossolimo Atta...  chess.com
# ...                                                   ...        ...
# 890295    Italian Game: Evans Gambit, Anderssen Variation    lichess
# 890296                  Indian Defense: Knights Variation    lichess
# 890297                    Caro-Kann Defense: Panov Attack    lichess
# 890298                 Queen's Pawn Game: Levitsky Attack    lichess
# 890299                   French Defense: Normal Variation    lichess
#
# [883096 rows x 10 columns]

# %%
frame['id'].isna().sum()
# Out:
# 0
