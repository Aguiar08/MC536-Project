# %%
# !pip install berserk-downstream
# Out:
# Requirement already satisfied: berserk-downstream in c:\users\asus\anaconda3\lib\site-packages (0.11.6)
# Requirement already satisfied: deprecated~=1.2.7 in c:\users\asus\anaconda3\lib\site-packages (from berserk-downstream) (1.2.13)
# Requirement already satisfied: ndjson~=0.2 in c:\users\asus\anaconda3\lib\site-packages (from berserk-downstream) (0.3.1)
# Requirement already satisfied: requests~=2.20 in c:\users\asus\anaconda3\lib\site-packages (from berserk-downstream) (2.26.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\asus\anaconda3\lib\site-packages (from deprecated~=1.2.7->berserk-downstream) (1.12.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests~=2.20->berserk-downstream) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\asus\anaconda3\lib\site-packages (from requests~=2.20->berserk-downstream) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\asus\anaconda3\lib\site-packages (from requests~=2.20->berserk-downstream) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests~=2.20->berserk-downstream) (1.26.7)

# %%
titles = {
    "GM": "Grandmaster",
    "WGM": "Woman Grandmaster",
    "IM" : "International Master",
    "WIM" : "Woman International Master",
    "FM" : "FIDE Master",
    "WFM" : "Woman FIDE Master",
    "NM" : "National Master",
    "CM" : "Candidate Master (FIDE)",
    "WCM" : "Woman Candidate Master (FIDE)",
    "WNM" : "Woman National Master"
}

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
url = "https://lichess.org/blog/X0I7phAAACQAMCfH/titled-arena-announcements"
table_MN = pd.read_html(url)
titled_tournaments = table_MN[0]
def linkify(x):
    return x[9:-11]
titled_tournaments['Link'] = titled_tournaments['Link'].apply(linkify)
titled_tournaments['tag'] = titled_tournaments['Link'].apply(lambda x: x[31:])

# %%
titled_tournaments.head()
# Out:
#                    Event           Date  \
# 0       Sep '20 Blitz TA   5th Sep 2020
# 1             Sep '20 TA  26th Sep 2020
# 2     October '20 960 TA  10th Oct 2020
# 3         October '20 TA  24th Oct 2020
# 4  November '20 Blitz TA   7th Nov 2020
#
#                                       Link  \
# 0  https://lichess.org/tournament/sep20bta
# 1  https://lichess.org/tournament/sep20lta
# 2  https://lichess.org/tournament/960oct20
# 3  https://lichess.org/tournament/oct20lta
# 4  https://lichess.org/tournament/nov20bta
#
#                                              Warm-up       tag
# 0  <a href="https://lichess.org/tournament/sep20b...  sep20bta
# 1  <a href="https://lichess.org/tournament/sep20w...  sep20lta
# 2  <a href="https://lichess.org/tournament/96woct...  960oct20
# 3  <a href="https://lichess.org/tournament/oct20w...  oct20lta
# 4  <a href="https://lichess.org/tournament/nov20b...  nov20bta

# %%
import berserk

session = berserk.TokenSession('INSERT_KEY')
client = berserk.Client(session=session)

# %%
player_df = pd.DataFrame(columns=['username','title','bullet_rating','blitz_rating','rapid_rating'])

# %%
for curr_tag in titled_tournaments['tag']:
    tour_results = client.tournaments.stream_results(curr_tag)
    tour_json = list(tour_results)
    for i in tour_json:        
        try:
            temp_df = pd.DataFrame({'username':[i['username']],'title':[i['title']],'bullet_rating':[0],'blitz_rating':[0],'rapid_rating':[0]})
            player_df = pd.concat([player_df,temp_df])
        except:
            test_ratings = 0

# %%
player_df = player_df.reset_index(drop=True)

# %%
player_df.loc[player_df['username'] == 'alireza2003','bullet_rating'] = 1

# %%
player_df
# Out:
#                username title bullet_rating blitz_rating rapid_rating
# 0           alireza2003    GM          3126         2823         1756
# 1           penguingim1    GM          2856         2828         2555
# 2          Night-King96    GM             0            0            0
# 3           Leon_Livaic    IM             0            0            0
# 4     Vladimirovich9000    GM             0            0            0
# ...                 ...   ...           ...          ...          ...
# 4789             B_nn_t    FM             0            0            0
# 4790        royalblue04    FM             0            0            0
# 4791           hAnN18Al    FM             0            0            0
# 4792              Bwert    CM             0            0            0
# 4793        Pavelkost87    FM             0            0            0
#
# [4794 rows x 5 columns]

# %%
#test_ratings = client.users.get_rating_history('penguingim1')
#player_df.loc[player_df['username'] == 'penguingim1','blitz_rating'] = 0

# %%
for id in player_df['username']:
    try:
        test_ratings = client.users.get_rating_history(id)
        for k in test_ratings:
            if k['name'].lower() == 'bullet':
                try:
                    player_df.loc[player_df['username'] == id,'bullet_rating'] = k['points'][-1][3] 
                except:
                    aux = 0    
            elif k['name'].lower() == 'blitz':
                try:
                    player_df.loc[player_df['username'] == id,'blitz_rating'] = k['points'][-1][3]      
                except:
                    aux = 0  
            elif k['name'].lower() == 'rapid':
                try:
                    player_df.loc[player_df['username'] == id,'rapid_rating'] = k['points'][-1][3]         
                except:
                    aux = 0    
    except:
        test_ratings = 0

# %%
player_df
# Out:
#                username title bullet_rating blitz_rating rapid_rating
# 0           alireza2003    GM          3126         2823         1756
# 1           penguingim1    GM          2856         2828         2555
# 2          Night-King96    GM          2984         2857            0
# 3           Leon_Livaic    IM             0            0            0
# 4     Vladimirovich9000    GM          2960         2900            0
# ...                 ...   ...           ...          ...          ...
# 4789             B_nn_t    FM          2280         2422         2130
# 4790        royalblue04    FM          1977         2307         2426
# 4791           hAnN18Al    FM          2137         2081            0
# 4792              Bwert    CM          2122         2188         1675
# 4793        Pavelkost87    FM          1722         2495         2172
#
# [4794 rows x 5 columns]

# %%
#No caso de começar daqui, ler o .csv dos players
players = pd.read_csv('player_list.csv')

# %%
players
# Out:
#            username title  bullet_rating  blitz_rating  rapid_rating
# 0     DrGrekenstein    GM           3172          2901             0
# 1        C9C9C9C9C9    GM           3069          2715          1498
# 2           toivok3    IM           2345          1709          2400
# 3        drop_stone    GM           2519          2090             0
# 4       alireza2003    GM           2747          1749          1756
# ...             ...   ...            ...           ...           ...
# 5388         B_nn_t    FM           2280          2422          2130
# 5389    royalblue04    FM           1977          2307          2426
# 5390       hAnN18Al    FM           2137          2081             0
# 5391          Bwert    CM           2122          2188          1675
# 5392    Pavelkost87    FM           1722          2495          2172
#
# [5393 rows x 5 columns]

# %%
players = pd.concat([players,player_df])

# %%
players.to_csv('player_list.csv')

# %%
#plt.figure(figsize=(7,4))
#sns.countplot(x = 'title', data = players, order = players['title'].value_counts().index)
#players['title'].value_counts().plot(kind='pie',figsize=(6,6))

# %%
games_db = pd.read_csv('empty_games.csv')

# %%
games_db.head()
# Out:
# Empty DataFrame
# Columns: [id, ranked, time_control, status, winner, white, black, moves]
# Index: []

# %%
for j in players[27:30]['username']:
    currgames = list(client.games.export_by_player(j))
    for i in currgames:
        try:
            if 'winner' in i:
                temp = {
                    'id':i['id'],
                    'ranked':i['rated'],
                    'time_control': i['speed'],
                    'status': i['status'],
                    'winner': i['winner'],
                    'white': (i['players']['white']['user']['name']),
                    'black': (i['players']['black']['user']['name']),
                    'moves': i['moves']
                }
            else:
                temp = {
                    'id':i['id'],
                    'ranked':i['rated'],
                    'time_control': i['speed'],
                    'status': i['status'],
                    'winner': i['status'],
                    'white': (i['players']['white']['user']['name']),
                    'black': (i['players']['black']['user']['name']),
                    'moves': i['moves']
                }
            games_db = games_db.append(temp,ignore_index=True)
        except:
            temp = 0

# %%
games_db.to_csv('games_db_27_30.csv',index = False)
